# %% [markdown]
# # Olympic Medals Data Analysis

# %%
import pandas as pd

# %%
summer = pd.read_csv('summer.csv')

# %%
summer.head()
pd.options.display.max_rows=100

# %% [markdown]
# ### Counting Mixed Events

# %% [markdown]
# #### counting mixed and pairs events:

# %%
summer.Event.str.lower().str.contains('mixed').sum()
# Out:
# 38

# %%
summer[summer.Event.str.lower().str.contains('mixed')].head(20)
# devide in half
# Out:
#       Year       City   Sport Discipline                   Athlete Country  \
# 635   1900      Paris  Tennis     Tennis    DOHERTY, Hugh Lawrence     ZZX
# 636   1900      Paris  Tennis     Tennis      WARDEN, Archibald A.     ZZX
# 637   1900      Paris  Tennis     Tennis   DOHERTY, Reginald Frank     GBR
# 638   1900      Paris  Tennis     Tennis  MAHONY, Harold Sergerson     ZZX
# 639   1900      Paris  Tennis     Tennis             JONES, Marion     ZZX
# 640   1900      Paris  Tennis     Tennis         ROSENBAUM, Hedwig     ZZX
# 641   1900      Paris  Tennis     Tennis         COOPER, Charlotte     GBR
# 642   1900      Paris  Tennis     Tennis           PREVOST, Hélène     ZZX
# 2767  1912  Stockholm  Tennis     Tennis       CANET, Albert Henri     FRA
# 2768  1912  Stockholm  Tennis     Tennis      SCHOMBURGK, Heinrich     GER
# 2769  1912  Stockholm  Tennis     Tennis        SETTERWALL, Gunnar     SWE
# ...

# %%
summer.Event.str.lower().str.contains('pairs').sum()
# Out:
# 12

# %%
summer[summer.Event.str.lower().str.contains('pairs')].tail(20)
# devide in half
# Out:
#       Year     City    Sport      Discipline              Athlete Country  \
# 1845  1908   London  Skating  Figure skating         SYERS, Edgar     GBR
# 1846  1908   London  Skating  Figure skating     BURGER, Heinrich     GER
# 1847  1908   London  Skating  Figure skating       JOHNSON, James     GBR
# 1848  1908   London  Skating  Figure skating      SYERS, Florence     GBR
# 1849  1908   London  Skating  Figure skating         HÜBLER, Anna     GER
# 1850  1908   London  Skating  Figure skating     JOHNSON, Phyllis     GBR
# 4020  1920  Antwerp  Skating  Figure skating      WILLIAMS, Basil     GBR
# 4021  1920  Antwerp  Skating  Figure skating    JAKOBSSON, Walter     FIN
# 4022  1920  Antwerp  Skating  Figure skating         BRYN, Yngvar     NOR
# 4023  1920  Antwerp  Skating  Figure skating     JOHNSON, Phyllis     GBR
# 4024  1920  Antwerp  Skating  Figure skating  JAKOBSSON, Ludowika     FIN
# 4025  1920  Antwerp  Skating  Figure skating         BRYN, Alexia     NOR
#
# ...

# %% [markdown]
# #### counting Equestrian events:

# %%
summer.Sport.str.lower().str.contains('equestrian').sum()
# Out:
# 939

# %%
summer[summer.Sport.str.lower().str.contains('equestrian')].tail(100)
# drop athlete and gender then drop duplicates
# Out:
#        Year     City       Sport Discipline                         Athlete  \
# 26121  2004   Athens  Equestrian    Jumping                    BECKER, Otto
# 26122  2004   Athens  Equestrian    Jumping                 KUTSCHER, Marco
# 26123  2004   Athens  Equestrian    Jumping                  KAPPLER, Chris
# 26124  2004   Athens  Equestrian    Jumping                    WARD, Mclain
# 26125  2004   Athens  Equestrian    Jumping                    WYLDE, Peter
# 26126  2004   Athens  Equestrian    Jumping           BENGTSSON, Rolf-Goran
# 26127  2004   Athens  Equestrian    Jumping                 ERIKSSON, Peter
# 26128  2004   Athens  Equestrian    Jumping              FREDERICSON, Peder
# 26129  2004   Athens  Equestrian    Jumping                  MADDEN, Beezie
# 26130  2004   Athens  Equestrian    Jumping                  BARYARD, Malin
# 28089  2008  Beijing  Equestrian   Dressage                   KEMMER, Heike
# ...
